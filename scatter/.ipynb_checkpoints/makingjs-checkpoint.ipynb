# %%
import pandas as pd
import numpy as np
import json

data_owid = "../data/owid-covid-data.csv"

data_owid_df = pd.read_csv(data_owid)

data_owid_df.rename(columns= {"location": "country_name"}, inplace= True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/tn/m51dm4nd5wv2rw2867yd_l_h0000gn/T/ipykernel_49639/755966937.py in <module>
#       5 data_owid = "data/owid-covid-data.csv"
#       6
# ----> 7 data_owid_df = pd.read_csv(data_owid)
#       8
#       9 data_owid_df.rename(columns= {"location": "country_name"}, inplace= True)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     699         if ioargs.encoding and "b" not in ioargs.mode:
#     700             # Encoding
# --> 701             handle = open(
#     702                 handle,
#     703                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/owid-covid-data.csv'

# %%
data_owid_df.head()
# Out:
#   iso_code continent country_name        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# 1             NaN           NaN                  37.746
# 2             NaN           NaN                  37.746
# 3             NaN           NaN                  37.746
# 4             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 65 columns]

# %%
data_owid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132016 entries, 0 to 132015
# Data columns (total 65 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   iso_code                                 132016 non-null  object
#  1   continent                                123581 non-null  object
#  2   country_name                             132016 non-null  object
#  3   date                                     132016 non-null  object
#  4   total_cases                              124789 non-null  float64
#  5   new_cases                                124787 non-null  float64
#  6   new_cases_smoothed                       123744 non-null  float64
#  7   total_deaths                             113696 non-null  float64
#  8   new_deaths                               113892 non-null  float64
#  9   new_deaths_smoothed                      123744 non-null  float64
#  10  total_cases_per_million                  124148 non-null  float64
#  11  new_cases_per_million                    124146 non-null  float64
#  12  new_cases_smoothed_per_million           123108 non-null  float64
#  13  total_deaths_per_million                 113068 non-null  float64
#  14  new_deaths_per_million                   113264 non-null  float64
#  15  new_deaths_smoothed_per_million          123108 non-null  float64
#  16  reproduction_rate                        104056 non-null  float64
#  17  icu_patients                             15792 non-null   float64
#  18  icu_patients_per_million                 15792 non-null   float64
#  19  hosp_patients                            18508 non-null   float64
#  20  hosp_patients_per_million                18508 non-null   float64
#  21  weekly_icu_admissions                    1280 non-null    float64
#  22  weekly_icu_admissions_per_million        1280 non-null    float64
#  23  weekly_hosp_admissions                   2150 non-null    float64
#  24  weekly_hosp_admissions_per_million       2150 non-null    float64
#  25  new_tests                                54811 non-null   float64
#  26  total_tests                              55003 non-null   float64
#  27  total_tests_per_thousand                 55003 non-null   float64
#  28  new_tests_per_thousand                   54811 non-null   float64
#  29  new_tests_smoothed                       66363 non-null   float64
#  30  new_tests_smoothed_per_thousand          66363 non-null   float64
#  31  positive_rate                            62363 non-null   float64
#  32  tests_per_case                           61706 non-null   float64
#  33  tests_units                              68363 non-null   object
#  34  total_vaccinations                       33042 non-null   float64
#  35  people_vaccinated                        31510 non-null   float64
#  36  people_fully_vaccinated                  28510 non-null   float64
#  37  total_boosters                           5689 non-null    float64
#  38  new_vaccinations                         27507 non-null   float64
#  39  new_vaccinations_smoothed                58858 non-null   float64
#  40  total_vaccinations_per_hundred           33042 non-null   float64
#  41  people_vaccinated_per_hundred            31510 non-null   float64
#  42  people_fully_vaccinated_per_hundred      28510 non-null   float64
#  43  total_boosters_per_hundred               5689 non-null    float64
#  44  new_vaccinations_smoothed_per_million    58858 non-null   float64
#  45  stringency_index                         107901 non-null  float64
#  46  population                               131079 non-null  float64
#  47  population_density                       119498 non-null  float64
#  48  median_age                               113870 non-null  float64
#  49  aged_65_older                            112610 non-null  float64
#  50  aged_70_older                            113248 non-null  float64
#  51  gdp_per_capita                           114618 non-null  float64
#  52  extreme_poverty                          76646 non-null   float64
#  53  cardiovasc_death_rate                    114116 non-null  float64
#  54  diabetes_prevalence                      117848 non-null  float64
#  55  female_smokers                           88899 non-null   float64
#  56  male_smokers                             87613 non-null   float64
#  57  handwashing_facilities                   57428 non-null   float64
#  58  hospital_beds_per_thousand               103706 non-null  float64
#  59  life_expectancy                          122728 non-null  float64
#  60  human_development_index                  114212 non-null  float64
#  61  excess_mortality_cumulative_absolute     4623 non-null    float64
#  62  excess_mortality_cumulative              4623 non-null    float64
#  63  excess_mortality                         4623 non-null    float64
#  64  excess_mortality_cumulative_per_million  4623 non-null    float64
# dtypes: float64(60), object(5)
# memory usage: 65.5+ MB

# %%
# recent = df[df.date == df.max_date]
final_data = data_owid_df[['iso_code', 'country_name', 'continent', 'date', 'total_cases_per_million', 'total_deaths_per_million', 'total_vaccinations_per_hundred', 'new_cases', 'new_cases_smoothed', 'new_vaccinations', 'new_vaccinations_smoothed', 'stringency_index']]
final_data.head()
# Out:
#   iso_code country_name continent        date  total_cases_per_million  \
# 0      AFG  Afghanistan      Asia  2020-02-24                    0.126
# 1      AFG  Afghanistan      Asia  2020-02-25                    0.126
# 2      AFG  Afghanistan      Asia  2020-02-26                    0.126
# 3      AFG  Afghanistan      Asia  2020-02-27                    0.126
# 4      AFG  Afghanistan      Asia  2020-02-28                    0.126
#
#    total_deaths_per_million  total_vaccinations_per_hundred  new_cases  \
# 0                       NaN                             NaN        5.0
# 1                       NaN                             NaN        0.0
# 2                       NaN                             NaN        0.0
# 3                       NaN                             NaN        0.0
# 4                       NaN                             NaN        0.0
#
#    new_cases_smoothed  new_vaccinations  new_vaccinations_smoothed  \
# 0                 NaN               NaN                        NaN
# 1                 NaN               NaN                        NaN
# 2                 NaN               NaN                        NaN
# 3                 NaN               NaN                        NaN
# 4                 NaN               NaN                        NaN
#
#    stringency_index
# 0              8.33
# 1              8.33
# 2              8.33
# 3              8.33
# 4              8.33

# %%
final_dict = final_data.to_dict(orient='records')
final_dict
# Out:
# [{'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-02-24',
#   'total_cases_per_million': 0.126,
#   'total_deaths_per_million': nan,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 5.0,
#   'new_cases_smoothed': nan,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 8.33},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-02-25',
#   'total_cases_per_million': 0.126,
#   'total_deaths_per_million': nan,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 0.0,
#   'new_cases_smoothed': nan,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 8.33},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-02-26',
#   'total_cases_per_million': 0.126,
#   'total_deaths_per_million': nan,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 0.0,
#   'new_cases_smoothed': nan,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 8.33},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-02-27',
#   'total_cases_per_million': 0.126,
#   'total_deaths_per_million': nan,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 0.0,
#   'new_cases_smoothed': nan,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 8.33},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-02-28',
#   'total_cases_per_million': 0.126,
#   'total_deaths_per_million': nan,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 0.0,
#   'new_cases_smoothed': nan,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 8.33},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-02-29',
#   'total_cases_per_million': 0.126,
#   'total_deaths_per_million': nan,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 0.0,
#   'new_cases_smoothed': 0.714,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 8.33},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-03-01',
#   'total_cases_per_million': 0.126,
#   'total_deaths_per_million': nan,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 0.0,
#   'new_cases_smoothed': 0.714,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 27.78},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-03-02',
#   'total_cases_per_million': 0.126,
#   'total_deaths_per_million': nan,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 0.0,
#   'new_cases_smoothed': 0.0,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 27.78},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-03-03',
#   'total_cases_per_million': 0.126,
#   'total_deaths_per_million': nan,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 0.0,
#   'new_cases_smoothed': 0.0,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 27.78},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-03-04',
#   'total_cases_per_million': 0.126,
#   'total_deaths_per_million': nan,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 0.0,
#   'new_cases_smoothed': 0.0,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 27.78},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-03-05',
#   'total_cases_per_million': 0.126,
#   'total_deaths_per_million': nan,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 0.0,
#   'new_cases_smoothed': 0.0,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 27.78},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-03-06',
#   'total_cases_per_million': 0.126,
#   'total_deaths_per_million': nan,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 0.0,
#   'new_cases_smoothed': 0.0,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 27.78},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-03-07',
#   'total_cases_per_million': 0.201,
#   'total_deaths_per_million': nan,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 3.0,
#   'new_cases_smoothed': 0.429,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 27.78},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-03-08',
#   'total_cases_per_million': 0.201,
#   'total_deaths_per_million': nan,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 0.0,
#   'new_cases_smoothed': 0.429,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 27.78},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-03-09',
#   'total_cases_per_million': 0.201,
#   'total_deaths_per_million': nan,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 0.0,
#   'new_cases_smoothed': 0.429,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 27.78},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-03-10',
#   'total_cases_per_million': 0.201,
#   'total_deaths_per_million': nan,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 0.0,
#   'new_cases_smoothed': 0.429,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 27.78},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-03-11',
#   'total_cases_per_million': 0.276,
#   'total_deaths_per_million': nan,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 3.0,
#   'new_cases_smoothed': 0.857,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 27.78},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-03-12',
#   'total_cases_per_million': 0.276,
#   'total_deaths_per_million': nan,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 0.0,
#   'new_cases_smoothed': 0.857,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 27.78},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-03-13',
#   'total_cases_per_million': 0.276,
#   'total_deaths_per_million': nan,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 0.0,
#   'new_cases_smoothed': 0.857,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 27.78},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-03-14',
#   'total_cases_per_million': 0.351,
#   'total_deaths_per_million': nan,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 3.0,
#   'new_cases_smoothed': 0.857,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 38.89},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-03-15',
#   'total_cases_per_million': 0.502,
#   'total_deaths_per_million': nan,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 6.0,
#   'new_cases_smoothed': 1.714,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 38.89},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-03-16',
#   'total_cases_per_million': 0.628,
#   'total_deaths_per_million': nan,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 5.0,
#   'new_cases_smoothed': 2.429,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 38.89},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-03-17',
#   'total_cases_per_million': 0.653,
#   'total_deaths_per_million': nan,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 1.0,
#   'new_cases_smoothed': 2.571,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 38.89},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-03-18',
#   'total_cases_per_million': 0.653,
#   'total_deaths_per_million': nan,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 0.0,
#   'new_cases_smoothed': 2.143,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 41.67},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-03-19',
#   'total_cases_per_million': 0.653,
#   'total_deaths_per_million': nan,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 0.0,
#   'new_cases_smoothed': 2.143,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 41.67},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-03-20',
#   'total_cases_per_million': 0.602,
#   'total_deaths_per_million': nan,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': -2.0,
#   'new_cases_smoothed': 1.857,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 41.67},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-03-21',
#   'total_cases_per_million': 0.602,
#   'total_deaths_per_million': nan,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 0.0,
#   'new_cases_smoothed': 1.429,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 41.67},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-03-22',
#   'total_cases_per_million': 0.854,
#   'total_deaths_per_million': nan,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 10.0,
#   'new_cases_smoothed': 2.0,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 41.67},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-03-23',
#   'total_cases_per_million': 1.004,
#   'total_deaths_per_million': 0.025,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 6.0,
#   'new_cases_smoothed': 2.143,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 41.67},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-03-24',
#   'total_cases_per_million': 1.054,
#   'total_deaths_per_million': 0.025,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 2.0,
#   'new_cases_smoothed': 2.286,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 50.93},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-03-25',
#   'total_cases_per_million': 1.858,
#   'total_deaths_per_million': 0.025,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 32.0,
#   'new_cases_smoothed': 6.857,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 59.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-03-26',
#   'total_cases_per_million': 2.008,
#   'total_deaths_per_million': 0.05,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 6.0,
#   'new_cases_smoothed': 7.714,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 59.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-03-27',
#   'total_cases_per_million': 2.284,
#   'total_deaths_per_million': 0.05,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 11.0,
#   'new_cases_smoothed': 9.571,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 59.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-03-28',
#   'total_cases_per_million': 2.661,
#   'total_deaths_per_million': 0.05,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 15.0,
#   'new_cases_smoothed': 11.714,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 67.59},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-03-29',
#   'total_cases_per_million': 2.862,
#   'total_deaths_per_million': 0.1,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 8.0,
#   'new_cases_smoothed': 11.429,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 67.59},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-03-30',
#   'total_cases_per_million': 2.862,
#   'total_deaths_per_million': 0.1,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 0.0,
#   'new_cases_smoothed': 10.571,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 67.59},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-03-31',
#   'total_cases_per_million': 4.167,
#   'total_deaths_per_million': 0.1,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 52.0,
#   'new_cases_smoothed': 17.714,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 67.59},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-04-01',
#   'total_cases_per_million': 4.82,
#   'total_deaths_per_million': 0.1,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 26.0,
#   'new_cases_smoothed': 16.857,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 67.59},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-04-02',
#   'total_cases_per_million': 5.899,
#   'total_deaths_per_million': 0.1,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 43.0,
#   'new_cases_smoothed': 22.143,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 67.59},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-04-03',
#   'total_cases_per_million': 6.753,
#   'total_deaths_per_million': 0.126,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 34.0,
#   'new_cases_smoothed': 25.429,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 67.59},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-04-04',
#   'total_cases_per_million': 6.778,
#   'total_deaths_per_million': 0.126,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 1.0,
#   'new_cases_smoothed': 23.429,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 67.59},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-04-05',
#   'total_cases_per_million': 7.506,
#   'total_deaths_per_million': 0.176,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 29.0,
#   'new_cases_smoothed': 26.429,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 78.7},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-04-06',
#   'total_cases_per_million': 8.46,
#   'total_deaths_per_million': 0.176,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 38.0,
#   'new_cases_smoothed': 31.857,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 78.7},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-04-07',
#   'total_cases_per_million': 9.213,
#   'total_deaths_per_million': 0.276,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 30.0,
#   'new_cases_smoothed': 28.714,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 78.7},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-04-08',
#   'total_cases_per_million': 10.619,
#   'total_deaths_per_million': 0.351,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 56.0,
#   'new_cases_smoothed': 33.0,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 78.7},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-04-09',
#   'total_cases_per_million': 11.146,
#   'total_deaths_per_million': 0.377,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 21.0,
#   'new_cases_smoothed': 29.857,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 78.7},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-04-10',
#   'total_cases_per_million': 13.079,
#   'total_deaths_per_million': 0.377,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 77.0,
#   'new_cases_smoothed': 36.0,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 78.7},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-04-11',
#   'total_cases_per_million': 13.079,
#   'total_deaths_per_million': 0.377,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 0.0,
#   'new_cases_smoothed': 35.857,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 78.7},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-04-12',
#   'total_cases_per_million': 13.932,
#   'total_deaths_per_million': 0.452,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 34.0,
#   'new_cases_smoothed': 36.571,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-04-13',
#   'total_cases_per_million': 15.238,
#   'total_deaths_per_million': 0.477,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 52.0,
#   'new_cases_smoothed': 38.571,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-04-14',
#   'total_cases_per_million': 16.694,
#   'total_deaths_per_million': 0.552,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 58.0,
#   'new_cases_smoothed': 42.571,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-04-15',
#   'total_cases_per_million': 19.33,
#   'total_deaths_per_million': 0.628,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 105.0,
#   'new_cases_smoothed': 49.571,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-04-16',
#   'total_cases_per_million': 19.932,
#   'total_deaths_per_million': 0.728,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 24.0,
#   'new_cases_smoothed': 50.0,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-04-17',
#   'total_cases_per_million': 21.212,
#   'total_deaths_per_million': 0.753,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 51.0,
#   'new_cases_smoothed': 46.286,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-04-18',
#   'total_cases_per_million': 22.794,
#   'total_deaths_per_million': 0.753,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 63.0,
#   'new_cases_smoothed': 55.286,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-04-19',
#   'total_cases_per_million': 23.421,
#   'total_deaths_per_million': 0.753,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 25.0,
#   'new_cases_smoothed': 54.0,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-04-20',
#   'total_cases_per_million': 25.003,
#   'total_deaths_per_million': 0.828,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 63.0,
#   'new_cases_smoothed': 55.571,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-04-21',
#   'total_cases_per_million': 25.756,
#   'total_deaths_per_million': 0.904,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 30.0,
#   'new_cases_smoothed': 51.571,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-04-22',
#   'total_cases_per_million': 27.413,
#   'total_deaths_per_million': 0.904,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 66.0,
#   'new_cases_smoothed': 46.0,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-04-23',
#   'total_cases_per_million': 29.521,
#   'total_deaths_per_million': 1.004,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 84.0,
#   'new_cases_smoothed': 54.571,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-04-24',
#   'total_cases_per_million': 30.777,
#   'total_deaths_per_million': 1.004,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 50.0,
#   'new_cases_smoothed': 54.429,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-04-25',
#   'total_cases_per_million': 33.387,
#   'total_deaths_per_million': 1.079,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 104.0,
#   'new_cases_smoothed': 60.286,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-04-26',
#   'total_cases_per_million': 36.726,
#   'total_deaths_per_million': 1.23,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 133.0,
#   'new_cases_smoothed': 75.714,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-04-27',
#   'total_cases_per_million': 38.433,
#   'total_deaths_per_million': 1.255,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 68.0,
#   'new_cases_smoothed': 76.429,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-04-28',
#   'total_cases_per_million': 42.751,
#   'total_deaths_per_million': 1.506,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 172.0,
#   'new_cases_smoothed': 96.714,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-04-29',
#   'total_cases_per_million': 45.864,
#   'total_deaths_per_million': 1.506,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 124.0,
#   'new_cases_smoothed': 105.0,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-04-30',
#   'total_cases_per_million': 45.864,
#   'total_deaths_per_million': 1.506,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 0.0,
#   'new_cases_smoothed': 93.0,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-05-01',
#   'total_cases_per_million': 54.499,
#   'total_deaths_per_million': 1.607,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 344.0,
#   'new_cases_smoothed': 135.0,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-05-02',
#   'total_cases_per_million': 61.98,
#   'total_deaths_per_million': 1.807,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 298.0,
#   'new_cases_smoothed': 162.714,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-05-03',
#   'total_cases_per_million': 61.98,
#   'total_deaths_per_million': 1.807,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 0.0,
#   'new_cases_smoothed': 143.714,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-05-04',
#   'total_cases_per_million': 61.98,
#   'total_deaths_per_million': 1.807,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 0.0,
#   'new_cases_smoothed': 134.0,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-05-05',
#   'total_cases_per_million': 61.98,
#   'total_deaths_per_million': 1.807,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 0.0,
#   'new_cases_smoothed': 109.429,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-05-06',
#   'total_cases_per_million': 80.933,
#   'total_deaths_per_million': 2.385,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 755.0,
#   'new_cases_smoothed': 199.571,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-05-07',
#   'total_cases_per_million': 85.15,
#   'total_deaths_per_million': 2.611,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 168.0,
#   'new_cases_smoothed': 223.571,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-05-08',
#   'total_cases_per_million': 89.443,
#   'total_deaths_per_million': 2.636,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 171.0,
#   'new_cases_smoothed': 198.857,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-05-09',
#   'total_cases_per_million': 89.443,
#   'total_deaths_per_million': 2.636,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 0.0,
#   'new_cases_smoothed': 156.286,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-05-10',
#   'total_cases_per_million': 110.505,
#   'total_deaths_per_million': 2.987,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 839.0,
#   'new_cases_smoothed': 276.143,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-05-11',
#   'total_cases_per_million': 117.082,
#   'total_deaths_per_million': 3.012,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 262.0,
#   'new_cases_smoothed': 313.571,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-05-12',
#   'total_cases_per_million': 124.688,
#   'total_deaths_per_million': 3.188,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 303.0,
#   'new_cases_smoothed': 356.857,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-05-13',
#   'total_cases_per_million': 124.688,
#   'total_deaths_per_million': 3.188,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 0.0,
#   'new_cases_smoothed': 249.0,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-05-14',
#   'total_cases_per_million': 134.026,
#   'total_deaths_per_million': 3.414,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 372.0,
#   'new_cases_smoothed': 278.143,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-05-15',
#   'total_cases_per_million': 151.95,
#   'total_deaths_per_million': 3.841,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 714.0,
#   'new_cases_smoothed': 355.714,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-05-16',
#   'total_cases_per_million': 160.711,
#   'total_deaths_per_million': 4.217,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 349.0,
#   'new_cases_smoothed': 405.571,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-05-17',
#   'total_cases_per_million': 166.56,
#   'total_deaths_per_million': 4.242,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 233.0,
#   'new_cases_smoothed': 319.0,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-05-18',
#   'total_cases_per_million': 177.53,
#   'total_deaths_per_million': 4.343,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 437.0,
#   'new_cases_smoothed': 344.0,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-05-19',
#   'total_cases_per_million': 192.166,
#   'total_deaths_per_million': 4.443,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 583.0,
#   'new_cases_smoothed': 384.0,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-05-20',
#   'total_cases_per_million': 204.466,
#   'total_deaths_per_million': 4.694,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 490.0,
#   'new_cases_smoothed': 454.0,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-05-21',
#   'total_cases_per_million': 217.796,
#   'total_deaths_per_million': 4.845,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 531.0,
#   'new_cases_smoothed': 476.714,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-05-22',
#   'total_cases_per_million': 231.352,
#   'total_deaths_per_million': 5.146,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 540.0,
#   'new_cases_smoothed': 451.857,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-05-23',
#   'total_cases_per_million': 249.828,
#   'total_deaths_per_million': 5.397,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 736.0,
#   'new_cases_smoothed': 507.143,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-05-24',
#   'total_cases_per_million': 267.802,
#   'total_deaths_per_million': 5.573,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 716.0,
#   'new_cases_smoothed': 576.143,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-05-25',
#   'total_cases_per_million': 280.655,
#   'total_deaths_per_million': 5.598,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 512.0,
#   'new_cases_smoothed': 586.857,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-05-26',
#   'total_cases_per_million': 299.156,
#   'total_deaths_per_million': 5.623,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 737.0,
#   'new_cases_smoothed': 608.857,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-05-27',
#   'total_cases_per_million': 312.912,
#   'total_deaths_per_million': 5.774,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 548.0,
#   'new_cases_smoothed': 617.143,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-05-28',
#   'total_cases_per_million': 328.903,
#   'total_deaths_per_million': 6.0,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 637.0,
#   'new_cases_smoothed': 632.286,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-05-29',
#   'total_cases_per_million': 345.045,
#   'total_deaths_per_million': 6.276,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 643.0,
#   'new_cases_smoothed': 647.0,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-05-30',
#   'total_cases_per_million': 364.726,
#   'total_deaths_per_million': 6.326,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 784.0,
#   'new_cases_smoothed': 653.857,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-05-31',
#   'total_cases_per_million': 381.068,
#   'total_deaths_per_million': 6.376,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 651.0,
#   'new_cases_smoothed': 644.571,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-06-01',
#   'total_cases_per_million': 397.536,
#   'total_deaths_per_million': 6.753,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 656.0,
#   'new_cases_smoothed': 665.143,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-06-02',
#   'total_cases_per_million': 416.162,
#   'total_deaths_per_million': 6.878,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 742.0,
#   'new_cases_smoothed': 665.857,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-06-03',
#   'total_cases_per_million': 435.617,
#   'total_deaths_per_million': 7.481,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 775.0,
#   'new_cases_smoothed': 698.286,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-06-04',
#   'total_cases_per_million': 451.282,
#   'total_deaths_per_million': 7.606,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 624.0,
#   'new_cases_smoothed': 696.429,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-06-05',
#   'total_cases_per_million': 478.343,
#   'total_deaths_per_million': 7.857,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 1078.0,
#   'new_cases_smoothed': 758.571,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-06-06',
#   'total_cases_per_million': 492.953,
#   'total_deaths_per_million': 8.309,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 582.0,
#   'new_cases_smoothed': 729.714,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-06-07',
#   'total_cases_per_million': 512.81,
#   'total_deaths_per_million': 9.062,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 791.0,
#   'new_cases_smoothed': 749.714,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-06-08',
#   'total_cases_per_million': 527.244,
#   'total_deaths_per_million': 9.364,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 575.0,
#   'new_cases_smoothed': 738.143,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 84.26},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-06-09',
#   'total_cases_per_million': 534.901,
#   'total_deaths_per_million': 9.539,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 305.0,
#   'new_cases_smoothed': 675.714,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 78.7},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-06-10',
#   'total_cases_per_million': 557.996,
#   'total_deaths_per_million': 10.267,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 920.0,
#   'new_cases_smoothed': 696.429,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 78.7},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-06-11',
#   'total_cases_per_million': 576.773,
#   'total_deaths_per_million': 10.794,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 748.0,
#   'new_cases_smoothed': 714.143,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 78.7},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-06-12',
#   'total_cases_per_million': 593.241,
#   'total_deaths_per_million': 11.296,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 656.0,
#   'new_cases_smoothed': 653.857,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 78.7},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-06-13',
#   'total_cases_per_million': 607.198,
#   'total_deaths_per_million': 11.422,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 556.0,
#   'new_cases_smoothed': 650.143,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 78.7},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-06-14',
#   'total_cases_per_million': 623.867,
#   'total_deaths_per_million': 11.924,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 664.0,
#   'new_cases_smoothed': 632.0,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 78.7},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-06-15',
#   'total_cases_per_million': 642.97,
#   'total_deaths_per_million': 12.05,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 761.0,
#   'new_cases_smoothed': 658.571,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 78.7},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-06-16',
#   'total_cases_per_million': 645.631,
#   'total_deaths_per_million': 12.25,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 106.0,
#   'new_cases_smoothed': 630.143,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 78.7},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-06-17',
#   'total_cases_per_million': 676.784,
#   'total_deaths_per_million': 12.752,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 1241.0,
#   'new_cases_smoothed': 676.0,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 78.7},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-06-18',
#   'total_cases_per_million': 688.407,
#   'total_deaths_per_million': 13.807,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 463.0,
#   'new_cases_smoothed': 635.286,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 78.7},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-06-19',
#   'total_cases_per_million': 701.988,
#   'total_deaths_per_million': 13.857,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 541.0,
#   'new_cases_smoothed': 618.857,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 78.7},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-06-20',
#   'total_cases_per_million': 712.506,
#   'total_deaths_per_million': 13.857,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 419.0,
#   'new_cases_smoothed': 599.286,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 78.7},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-06-21',
#   'total_cases_per_million': 725.962,
#   'total_deaths_per_million': 14.685,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 536.0,
#   'new_cases_smoothed': 581.0,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 78.7},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-06-22',
#   'total_cases_per_million': 733.744,
#   'total_deaths_per_million': 15.112,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 310.0,
#   'new_cases_smoothed': 516.571,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 78.7},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-06-23',
#   'total_cases_per_million': 742.229,
#   'total_deaths_per_million': 15.614,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 338.0,
#   'new_cases_smoothed': 549.714,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 78.7},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-06-24',
#   'total_cases_per_million': 746.22,
#   'total_deaths_per_million': 16.141,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 159.0,
#   'new_cases_smoothed': 395.143,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 78.7},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-06-25',
#   'total_cases_per_million': 759.65,
#   'total_deaths_per_million': 17.045,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 535.0,
#   'new_cases_smoothed': 405.429,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 78.7},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-06-26',
#   'total_cases_per_million': 761.784,
#   'total_deaths_per_million': 17.171,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 85.0,
#   'new_cases_smoothed': 340.286,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 78.7},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-06-27',
#   'total_cases_per_million': 770.721,
#   'total_deaths_per_million': 17.748,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 356.0,
#   'new_cases_smoothed': 331.286,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 78.7},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-06-28',
#   'total_cases_per_million': 779.532,
#   'total_deaths_per_million': 18.401,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 351.0,
#   'new_cases_smoothed': 304.857,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 78.7},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-06-29',
#   'total_cases_per_million': 786.335,
#   'total_deaths_per_million': 18.501,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 271.0,
#   'new_cases_smoothed': 299.286,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 78.7},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-06-30',
#   'total_cases_per_million': 789.373,
#   'total_deaths_per_million': 18.551,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 121.0,
#   'new_cases_smoothed': 268.286,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 78.7},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-07-01',
#   'total_cases_per_million': 799.489,
#   'total_deaths_per_million': 19.53,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 403.0,
#   'new_cases_smoothed': 303.143,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 78.7},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-07-02',
#   'total_cases_per_million': 806.016,
#   'total_deaths_per_million': 20.359,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 260.0,
#   'new_cases_smoothed': 263.857,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 78.7},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-07-03',
#   'total_cases_per_million': 813.597,
#   'total_deaths_per_million': 20.66,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 302.0,
#   'new_cases_smoothed': 294.857,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 78.7},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-07-04',
#   'total_cases_per_million': 822.333,
#   'total_deaths_per_million': 20.836,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 348.0,
#   'new_cases_smoothed': 293.714,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'stringency_index': 78.7},
#  {'iso_code': 'AFG',
#   'country_name': 'Afghanistan',
#   'continent': 'Asia',
#   'date': '2020-07-05',
#   'total_cases_per_million': 829.337,
#   'total_deaths_per_million': 21.79,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 279.0,
#   'new_cases_smoothed': 283.429,
#   'new_vaccinations': nan,
# ...
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-01-11',
#   'total_cases_per_million': 2245.442,
#   'total_deaths_per_million': 53.435,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 28004.0,
#   'new_cases_smoothed': 32745.857,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': 500.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-01-12',
#   'total_cases_per_million': 2264.419,
#   'total_deaths_per_million': 54.217,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 26065.0,
#   'new_cases_smoothed': 32635.0,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': 500.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-01-13',
#   'total_cases_per_million': 2289.218,
#   'total_deaths_per_million': 55.106,
#   'total_vaccinations_per_hundred': 0.0,
#   'new_cases': 34061.0,
#   'new_cases_smoothed': 32387.0,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': 500.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-01-14',
#   'total_cases_per_million': 2314.152,
#   'total_deaths_per_million': 55.873,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 34246.0,
#   'new_cases_smoothed': 32218.0,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': 600.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-01-15',
#   'total_cases_per_million': 2337.128,
#   'total_deaths_per_million': 56.532,
#   'total_vaccinations_per_hundred': 0.0,
#   'new_cases': 31558.0,
#   'new_cases_smoothed': 31520.571,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': 667.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-01-16',
#   'total_cases_per_million': 2357.171,
#   'total_deaths_per_million': 57.014,
#   'total_vaccinations_per_hundred': 0.0,
#   'new_cases': 27528.0,
#   'new_cases_smoothed': 30442.857,
#   'new_vaccinations': 3000.0,
#   'new_vaccinations_smoothed': 1000.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-01-17',
#   'total_cases_per_million': 2376.558,
#   'total_deaths_per_million': 57.449,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 26628.0,
#   'new_cases_smoothed': 29727.143,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': 1118.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-01-18',
#   'total_cases_per_million': 2392.885,
#   'total_deaths_per_million': 57.978,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 22425.0,
#   'new_cases_smoothed': 28930.143,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': 1236.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-01-19',
#   'total_cases_per_million': 2409.976,
#   'total_deaths_per_million': 58.853,
#   'total_vaccinations_per_hundred': 0.0,
#   'new_cases': 23475.0,
#   'new_cases_smoothed': 28560.143,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': 1354.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-01-20',
#   'total_cases_per_million': 2430.607,
#   'total_deaths_per_million': 59.524,
#   'total_vaccinations_per_hundred': 0.0,
#   'new_cases': 28336.0,
#   'new_cases_smoothed': 27742.286,
#   'new_vaccinations': 2187.0,
#   'new_vaccinations_smoothed': 1595.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-01-21',
#   'total_cases_per_million': 2450.957,
#   'total_deaths_per_million': 60.271,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 27950.0,
#   'new_cases_smoothed': 26842.857,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': 1718.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-01-22',
#   'total_cases_per_million': 2469.872,
#   'total_deaths_per_million': 60.98,
#   'total_vaccinations_per_hundred': 0.0,
#   'new_cases': 25980.0,
#   'new_cases_smoothed': 26046.0,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': 1841.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-01-23',
#   'total_cases_per_million': 2489.795,
#   'total_deaths_per_million': 61.549,
#   'total_vaccinations_per_hundred': 0.0,
#   'new_cases': 27364.0,
#   'new_cases_smoothed': 26022.571,
#   'new_vaccinations': 1463.0,
#   'new_vaccinations_smoothed': 1622.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-01-24',
#   'total_cases_per_million': 2504.488,
#   'total_deaths_per_million': 62.02,
#   'total_vaccinations_per_hundred': 0.0,
#   'new_cases': 20181.0,
#   'new_cases_smoothed': 25101.571,
#   'new_vaccinations': 0.0,
#   'new_vaccinations_smoothed': 1433.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-01-25',
#   'total_cases_per_million': 2516.608,
#   'total_deaths_per_million': 62.582,
#   'total_vaccinations_per_hundred': 0.0,
#   'new_cases': 16646.0,
#   'new_cases_smoothed': 24276.0,
#   'new_vaccinations': 1536.0,
#   'new_vaccinations_smoothed': 1463.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-01-26',
#   'total_cases_per_million': 2530.147,
#   'total_deaths_per_million': 63.297,
#   'total_vaccinations_per_hundred': 0.0,
#   'new_cases': 18595.0,
#   'new_cases_smoothed': 23578.857,
#   'new_vaccinations': 2823.0,
#   'new_vaccinations_smoothed': 1677.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-01-27',
#   'total_cases_per_million': 2545.336,
#   'total_deaths_per_million': 64.063,
#   'total_vaccinations_per_hundred': 0.0,
#   'new_cases': 20862.0,
#   'new_cases_smoothed': 22511.143,
#   'new_vaccinations': 2875.0,
#   'new_vaccinations_smoothed': 1775.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-01-28',
#   'total_cases_per_million': 2560.464,
#   'total_deaths_per_million': 64.788,
#   'total_vaccinations_per_hundred': 0.0,
#   'new_cases': 20778.0,
#   'new_cases_smoothed': 21486.571,
#   'new_vaccinations': 3192.0,
#   'new_vaccinations_smoothed': 1965.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-01-29',
#   'total_cases_per_million': 2574.447,
#   'total_deaths_per_million': 65.404,
#   'total_vaccinations_per_hundred': 0.0,
#   'new_cases': 19206.0,
#   'new_cases_smoothed': 20518.857,
#   'new_vaccinations': 2082.0,
#   'new_vaccinations_smoothed': 1996.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-01-30',
#   'total_cases_per_million': 2587.456,
#   'total_deaths_per_million': 65.851,
#   'total_vaccinations_per_hundred': 0.01,
#   'new_cases': 17868.0,
#   'new_cases_smoothed': 19162.286,
#   'new_vaccinations': 91345.0,
#   'new_vaccinations_smoothed': 14836.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-01-31',
#   'total_cases_per_million': 2598.932,
#   'total_deaths_per_million': 66.233,
#   'total_vaccinations_per_hundred': 0.01,
#   'new_cases': 15762.0,
#   'new_cases_smoothed': 18531.0,
#   'new_vaccinations': 36000.0,
#   'new_vaccinations_smoothed': 19979.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-02-01',
#   'total_cases_per_million': 2608.181,
#   'total_deaths_per_million': 66.603,
#   'total_vaccinations_per_hundred': 0.02,
#   'new_cases': 12703.0,
#   'new_cases_smoothed': 17967.714,
#   'new_vaccinations': 78506.0,
#   'new_vaccinations_smoothed': 30975.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-02-02',
#   'total_cases_per_million': 2618.964,
#   'total_deaths_per_million': 67.247,
#   'total_vaccinations_per_hundred': 0.02,
#   'new_cases': 14810.0,
#   'new_cases_smoothed': 17427.0,
#   'new_vaccinations': 58415.0,
#   'new_vaccinations_smoothed': 38916.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-02-03',
#   'total_cases_per_million': 2630.222,
#   'total_deaths_per_million': 67.764,
#   'total_vaccinations_per_hundred': 0.03,
#   'new_cases': 15463.0,
#   'new_cases_smoothed': 16655.714,
#   'new_vaccinations': 52022.0,
#   'new_vaccinations_smoothed': 45937.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-02-04',
#   'total_cases_per_million': 2642.209,
#   'total_deaths_per_million': 68.177,
#   'total_vaccinations_per_hundred': 0.03,
#   'new_cases': 16465.0,
#   'new_cases_smoothed': 16039.571,
#   'new_vaccinations': 43325.0,
#   'new_vaccinations_smoothed': 51671.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-02-05',
#   'total_cases_per_million': 2653.809,
#   'total_deaths_per_million': 68.575,
#   'total_vaccinations_per_hundred': 0.03,
#   'new_cases': 15932.0,
#   'new_cases_smoothed': 15571.857,
#   'new_vaccinations': 56512.0,
#   'new_vaccinations_smoothed': 59446.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-02-06',
#   'total_cases_per_million': 2663.522,
#   'total_deaths_per_million': 68.973,
#   'total_vaccinations_per_hundred': 0.04,
#   'new_cases': 13340.0,
#   'new_cases_smoothed': 14925.0,
#   'new_vaccinations': 57814.0,
#   'new_vaccinations_smoothed': 54656.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-02-07',
#   'total_cases_per_million': 2672.216,
#   'total_deaths_per_million': 69.233,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 11941.0,
#   'new_cases_smoothed': 14379.143,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': 55849.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-02-08',
#   'total_cases_per_million': 2680.487,
#   'total_deaths_per_million': 69.557,
#   'total_vaccinations_per_hundred': 0.04,
#   'new_cases': 11360.0,
#   'new_cases_smoothed': 14187.286,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': 50970.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-02-09',
#   'total_cases_per_million': 2688.709,
#   'total_deaths_per_million': 70.065,
#   'total_vaccinations_per_hundred': 0.05,
#   'new_cases': 11293.0,
#   'new_cases_smoothed': 13684.857,
#   'new_vaccinations': 67761.0,
#   'new_vaccinations_smoothed': 52305.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-02-10',
#   'total_cases_per_million': 2698.26,
#   'total_deaths_per_million': 70.456,
#   'total_vaccinations_per_hundred': 0.06,
#   'new_cases': 13118.0,
#   'new_cases_smoothed': 13349.857,
#   'new_vaccinations': 134573.0,
#   'new_vaccinations_smoothed': 64098.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-02-11',
#   'total_cases_per_million': 2706.936,
#   'total_deaths_per_million': 70.816,
#   'total_vaccinations_per_hundred': 0.07,
#   'new_cases': 11917.0,
#   'new_cases_smoothed': 12700.143,
#   'new_vaccinations': 112960.0,
#   'new_vaccinations_smoothed': 74046.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-02-12',
#   'total_cases_per_million': 2717.057,
#   'total_deaths_per_million': 71.227,
#   'total_vaccinations_per_hundred': 0.08,
#   'new_cases': 13901.0,
#   'new_cases_smoothed': 12410.0,
#   'new_vaccinations': 256785.0,
#   'new_vaccinations_smoothed': 102656.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-02-13',
#   'total_cases_per_million': 2725.016,
#   'total_deaths_per_million': 71.483,
#   'total_vaccinations_per_hundred': 0.11,
#   'new_cases': 10931.0,
#   'new_cases_smoothed': 12065.857,
#   'new_vaccinations': 280597.0,
#   'new_vaccinations_smoothed': 134483.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-02-14',
#   'total_cases_per_million': 2732.598,
#   'total_deaths_per_million': 71.697,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 10415.0,
#   'new_cases_smoothed': 11847.857,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': 151062.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-02-15',
#   'total_cases_per_million': 2739.767,
#   'total_deaths_per_million': 72.039,
#   'total_vaccinations_per_hundred': 0.13,
#   'new_cases': 9846.0,
#   'new_cases_smoothed': 11631.571,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': 167642.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-02-16',
#   'total_cases_per_million': 2747.041,
#   'total_deaths_per_million': 72.378,
#   'total_vaccinations_per_hundred': 0.14,
#   'new_cases': 9990.0,
#   'new_cases_smoothed': 11445.429,
#   'new_vaccinations': 198820.0,
#   'new_vaccinations_smoothed': 186365.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-02-17',
#   'total_cases_per_million': 2755.897,
#   'total_deaths_per_million': 72.671,
#   'total_vaccinations_per_hundred': 0.16,
#   'new_cases': 12164.0,
#   'new_cases_smoothed': 11309.143,
#   'new_vaccinations': 181840.0,
#   'new_vaccinations_smoothed': 193118.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-02-18',
#   'total_cases_per_million': 2766.125,
#   'total_deaths_per_million': 73.044,
#   'total_vaccinations_per_hundred': 0.17,
#   'new_cases': 14048.0,
#   'new_cases_smoothed': 11613.571,
#   'new_vaccinations': 156344.0,
#   'new_vaccinations_smoothed': 199315.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-02-19',
#   'total_cases_per_million': 2774.166,
#   'total_deaths_per_million': 73.324,
#   'total_vaccinations_per_hundred': 0.18,
#   'new_cases': 11044.0,
#   'new_cases_smoothed': 11205.429,
#   'new_vaccinations': 210035.0,
#   'new_vaccinations_smoothed': 192637.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-02-20',
#   'total_cases_per_million': 2781.111,
#   'total_deaths_per_million': 73.535,
#   'total_vaccinations_per_hundred': 0.19,
#   'new_cases': 9539.0,
#   'new_cases_smoothed': 11006.571,
#   'new_vaccinations': 102932.0,
#   'new_vaccinations_smoothed': 167256.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-02-21',
#   'total_cases_per_million': 2788.035,
#   'total_deaths_per_million': 73.78,
#   'total_vaccinations_per_hundred': 0.19,
#   'new_cases': 9511.0,
#   'new_cases_smoothed': 10877.429,
#   'new_vaccinations': 6765.0,
#   'new_vaccinations_smoothed': 145307.0,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2021-02-22',
#   'total_cases_per_million': 2794.602,
#   'total_deaths_per_million': 74.024,
#   'total_vaccinations_per_hundred': 0.2,
#   'new_cases': 9019.0,
#   'new_cases_smoothed': 10759.286,
#   'new_vaccinations': 122163.0,
#   'new_vaccinations_smoothed': 139843.0,
#   'stringency_index': nan},
#  ...]

# %%
# with open('','r') as f:
#     data = json.loads(f.read())
# features = data['features']

# %%
# geo = pd.DataFrame(features)
# geo.head()

# %%
# pd.DataFrame(geo['properties'][1], index = [0])

# %%
# list = []

# for x in range(0,len(geo['properties'])):
#     country_data = pd.DataFrame(geo['properties'][x], index = [x])
#     list.append(country_data)
# properties = pd.concat(list).rename(columns = {'ADMIN': 'country_name', 'ISO_A3' : 'iso_code'})
# properties = properties['iso_code']
# properties.head()

# %%
# merged = pd.merge(properties, recent, on = ['iso_code'], how = 'left')
# merged.head()

# %%
# merged[merged.iso_code == 'USA']

# %%
# properties_new = merged.to_dict(orient='records')
# properties_new

# %%
# geo['properties_new'] = properties_new
# geo.head()

# %%
# geo_new = geo[['type', 'properties_new', 'geometry']].rename(columns = {'properties_new': 'properties'})
# geo_new.head()

# %%
# features_new = geo_new.to_dict(orient='records')
# data['features'] = features_new
# data

# %%
with open('new_df.js', 'w') as f:
    json.dump(final_dict, f)
