# %%
import pandas as pd
import numpy as np
import json

data_owid = "../data/owid-covid-data.csv"

data_owid_df = pd.read_csv(data_owid)

data_owid_df.rename(columns= {"location": "country_name"}, inplace= True)

# %%
data_owid_df.head()
# Out:
#   iso_code continent country_name        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
data_owid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132016 entries, 0 to 132015
# Data columns (total 65 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   iso_code                                 132016 non-null  object
#  1   continent                                123581 non-null  object
#  2   country_name                             132016 non-null  object
#  3   date                                     132016 non-null  object
#  4   total_cases                              124789 non-null  float64
#  5   new_cases                                124787 non-null  float64
#  6   new_cases_smoothed                       123744 non-null  float64
#  7   total_deaths                             113696 non-null  float64
#  8   new_deaths                               113892 non-null  float64
#  9   new_deaths_smoothed                      123744 non-null  float64
# ...

# %%
# data_owid_df['date']= pd.to_datetime(data_owid_df['date'])

# max_date = data_owid_df.groupby('country_name')['date'].max()
# max_date.rename("max_date", inplace= True)
# max_date.head()

# %%
# df = pd.merge(data_owid_df, max_date, on='country_name', how='outer')
# df[df.iso_code == 'USA']

# %%
continent_list = data_owid_df.continent.unique()
print(continent_list)
continents = data_owid_df[data_owid_df.country_name.isin(continent_list)]
final_data = continents[['iso_code', 'country_name', 'continent', 'date', 'total_cases_per_million', 'total_deaths_per_million', 'total_vaccinations_per_hundred', 'new_cases', 'new_cases_smoothed', 'new_vaccinations', 'new_vaccinations_smoothed', 'new_vaccinations_smoothed_per_million', 'new_cases_smoothed_per_million', 'stringency_index']]
final_data.head()
# Out:
# ['Asia' nan 'Europe' 'Africa' 'North America' 'South America' 'Oceania']
#      iso_code country_name continent        date  total_cases_per_million  \
# 624  OWID_AFR       Africa       NaN  2020-02-13                      NaN
# 625  OWID_AFR       Africa       NaN  2020-02-14                    0.001
# 626  OWID_AFR       Africa       NaN  2020-02-15                    0.001
# 627  OWID_AFR       Africa       NaN  2020-02-16                    0.001
# 628  OWID_AFR       Africa       NaN  2020-02-17                    0.001
#
#      total_deaths_per_million  total_vaccinations_per_hundred  new_cases  \
# 624                       NaN                             NaN        0.0
# 625                       NaN                             NaN        1.0
# 626                       NaN                             NaN        0.0
# 627                       NaN                             NaN        0.0
# 628                       NaN                             NaN        0.0
#
# ...

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3885 entries, 624 to 109939
# Data columns (total 14 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               3885 non-null   object
#  1   country_name                           3885 non-null   object
#  2   continent                              0 non-null      object
#  3   date                                   3885 non-null   object
#  4   total_cases_per_million                3881 non-null   float64
#  5   total_deaths_per_million               3751 non-null   float64
#  6   total_vaccinations_per_hundred         1883 non-null   float64
#  7   new_cases                              3885 non-null   float64
#  8   new_cases_smoothed                     3849 non-null   float64
#  9   new_vaccinations                       1868 non-null   float64
# ...

# %%
final_data.new_vaccinations_smoothed_per_million.max()
# Out:
# 9018.0

# %%
final_dict = final_data.to_dict(orient='records')
final_dict
# Out:
# [{'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2020-02-13',
#   'total_cases_per_million': nan,
#   'total_deaths_per_million': nan,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 0.0,
#   'new_cases_smoothed': nan,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'new_vaccinations_smoothed_per_million': nan,
#   'new_cases_smoothed_per_million': nan,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
#   'continent': nan,
#   'date': '2020-02-14',
#   'total_cases_per_million': 0.001,
#   'total_deaths_per_million': nan,
#   'total_vaccinations_per_hundred': nan,
#   'new_cases': 1.0,
#   'new_cases_smoothed': nan,
#   'new_vaccinations': nan,
#   'new_vaccinations_smoothed': nan,
#   'new_vaccinations_smoothed_per_million': nan,
#   'new_cases_smoothed_per_million': nan,
#   'stringency_index': nan},
#  {'iso_code': 'OWID_AFR',
#   'country_name': 'Africa',
# ...

# %%
# with open('new_df.js', 'w') as f:
#     json.dump(final_dict, f)

# %%
with open('continents.js', 'w') as f:
    json.dump(final_dict, f)
